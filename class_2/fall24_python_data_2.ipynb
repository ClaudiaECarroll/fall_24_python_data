# %% [markdown]
# ## Demo 1 - Pandas Review #

# %%
import pandas as pd

# %%
#Using pandas to open a dataframe from the contents of the csv file gdp_africa.csv.
#Saving the contents of the csv file to variable df

df_europe = pd.read_csv("gdp_europe.csv", index_col=0)

# %%
df_europe
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
#printing the first three rows of the dataframe

df_europe.head(3)
# Out:
#          gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Albania     1601.056136     1942.284244     2312.888958     2760.196931
# Austria     6137.076492     8842.598030    10750.721110    12834.602400
# Belgium     8343.105127     9714.960623    10991.206760    13149.041190
#
#          gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Albania     3313.422188      3533.00391     3630.880722     3738.932735
# Austria    16661.625600     19749.42230    21597.083620    23687.826070
# Belgium    16672.143560     19117.97448    20979.845890    22525.563080
#
#          gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Albania     2497.437901     3193.054604     4604.211737     5937.029526
# Austria    27042.018680    29095.920660    32417.607690    36126.492700
# Belgium    25575.570690    27561.196630    30485.883750    33692.605080

# %%
#Printing the last few rows of the dataframe

df_europe.tail(10)
# Out:
#                  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Portugal            3068.319867     3774.571743     4727.954889
# Romania             3144.613186     3943.370225     4734.997586
# Serbia              3581.459448     4981.090891     6289.629157
# Slovak Republic     5074.659104     6093.262980     7481.107598
# Slovenia            4215.041741     5862.276629     7402.303395
# Spain               3834.034742     4564.802410     5693.843879
# Sweden              8527.844662     9911.878226    12329.441920
# Switzerland        14734.232750    17909.489730    20431.092700
# Turkey              1969.100980     2218.754257     2322.869908
# United Kingdom      9979.508487    11283.177950    12477.177070
#
#                  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Portugal            6361.517993     9022.247417    10172.485720
# Romania             6470.866545     8011.414402     9356.397240
# ...

# %%
#Getting summary info about the dataframe

df_europe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30 entries, Albania to United Kingdom
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gdpPercap_1952  30 non-null     float64
#  1   gdpPercap_1957  30 non-null     float64
#  2   gdpPercap_1962  30 non-null     float64
#  3   gdpPercap_1967  30 non-null     float64
#  4   gdpPercap_1972  30 non-null     float64
#  5   gdpPercap_1977  30 non-null     float64
#  6   gdpPercap_1982  30 non-null     float64
#  7   gdpPercap_1987  30 non-null     float64
#  8   gdpPercap_1992  30 non-null     float64
#  9   gdpPercap_1997  30 non-null     float64
#  10  gdpPercap_2002  30 non-null     float64
#  11  gdpPercap_2007  30 non-null     float64
# dtypes: float64(12)
# memory usage: 3.0+ KB

# %%
#Getting summary statistics about the dataframe

df_europe.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       30.000000       30.000000       30.000000       30.000000
# mean      5661.057435     6963.012816     8365.486814    10143.823757
# std       3114.060493     3677.950146     4199.193906     4724.983889
# min        973.533195     1353.989176     1709.683679     2172.352423
# 25%       3241.132406     4394.874315     5373.536612     6657.939047
# 50%       5142.469716     6066.721495     7515.733737     9366.067033
# 75%       7236.794919     9597.220820    10931.085348    13277.182058
# max      14734.232750    17909.489730    20431.092700    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       30.000000       30.000000       30.000000       30.000000
# mean     12479.575246    14283.979110    15617.896551    17214.310727
# std       5509.691411     5874.464896     6453.234827     7482.957960
# ...

# %%
#Slicing a **column** of the dataframe

df_europe["gdpPercap_1952"]

# %%
#Slicing two columns--note the double square brackets

df_europe[["gdpPercap_1952", "gdpPercap_1962"]]

# %%
#Slicing a **row** of a dataframe--note the difference to slicing a column

df_europe.loc["Belgium"]

# %%
#Slicing multiple rows--again, note the double square brackets

df_europe.loc[["Belgium", "Slovenia", "Austria"]]

# %%
#Getting a particular cell's value based on column and row headings

df_europe.loc["Belgium", "gdpPercap_1952"]

# %%
#Getting a subset of data using a slice of both rows and columns

df_europe.loc['Italy':'Poland', 'gdpPercap_1962':'gdpPercap_1972']

# %%
# Getting a slice of the dataframe between two columns

df2 = df_europe.loc[:, 'gdpPercap_1962':'gdpPercap_1972']
df2.head()

# %%
df3 = df_europe.loc['Italy':'Poland', :]
df3.head()

# %%
#Find the minimum value in a particular **column**

df_europe["gdpPercap_1952"].min()

# %%
#Find the minimum value in a particular **row**

df_europe.loc["Belgium"].max()

# %%
#Get the mean GDP of every column in the dataset

df_europe.mean()

# %%
#Get the mean value of a particular column

df_europe["gdpPercap_1952"].mean()

# %%
#Extracting the names of the columns

years = df_europe.columns.values
print(years)
# Out:
# ['gdpPercap_1952' 'gdpPercap_1957' 'gdpPercap_1962' 'gdpPercap_1967'
#  'gdpPercap_1972' 'gdpPercap_1977' 'gdpPercap_1982' 'gdpPercap_1987'
#  'gdpPercap_1992' 'gdpPercap_1997' 'gdpPercap_2002' 'gdpPercap_2007']

# %%
#Extracting the names of rows

countries = df_europe.index.values
print(countries)
# Out:
# ['Albania' 'Austria' 'Belgium' 'Bosnia and Herzegovina' 'Bulgaria'
#  'Croatia' 'Czech Republic' 'Denmark' 'Finland' 'France' 'Germany'
#  'Greece' 'Hungary' 'Iceland' 'Ireland' 'Italy' 'Montenegro' 'Netherlands'
#  'Norway' 'Poland' 'Portugal' 'Romania' 'Serbia' 'Slovak Republic'
#  'Slovenia' 'Spain' 'Sweden' 'Switzerland' 'Turkey' 'United Kingdom']

# %% [markdown]
# ## Dealing with Null Data

# %%
import pandas as pd

# %%
df_SAFI = pd.read_csv("SAFI_results.csv")

# %%
df_SAFI.head()
# Out:
#    Column1 A01_interview_date  A03_quest_no                 A04_start  \
# 0        0         17/11/2016             1  2017-03-23T09:49:57.000Z
# 1        1         17/11/2016             1  2017-04-02T09:48:16.000Z
# 2        2         17/11/2016             3  2017-04-02T14:35:26.000Z
# 3        3         17/11/2016             4  2017-04-02T14:55:18.000Z
# 4        4         17/11/2016             5  2017-04-02T15:10:35.000Z
#
#                     A05_end A06_province A07_district A08_ward A09_village  \
# 0  2017-04-02T17:29:08.000Z    Province1    District1    Ward2    Village2
# 1  2017-04-02T17:26:19.000Z    Province1    District1    Ward2    Village2
# 2  2017-04-02T17:26:53.000Z    Province1    District1    Ward2    Village2
# 3  2017-04-02T17:27:16.000Z    Province1    District1    Ward2    Village2
# 4  2017-04-02T17:27:35.000Z    Province1    District1    Ward2    Village2
#
#    A11_years_farm  ... F13_du_look_aftr_cows F_liv_count  G01_no_meals  \
# ...

# %%
#Removing a column from a dataframe

df2 = df_SAFI.drop(["Column1"], axis='columns')
df2.head()
# Out:
#   A01_interview_date  A03_quest_no                 A04_start  \
# 0         17/11/2016             1  2017-03-23T09:49:57.000Z
# 1         17/11/2016             1  2017-04-02T09:48:16.000Z
# 2         17/11/2016             3  2017-04-02T14:35:26.000Z
# 3         17/11/2016             4  2017-04-02T14:55:18.000Z
# 4         17/11/2016             5  2017-04-02T15:10:35.000Z
#
#                     A05_end A06_province A07_district A08_ward A09_village  \
# 0  2017-04-02T17:29:08.000Z    Province1    District1    Ward2    Village2
# 1  2017-04-02T17:26:19.000Z    Province1    District1    Ward2    Village2
# 2  2017-04-02T17:26:53.000Z    Province1    District1    Ward2    Village2
# 3  2017-04-02T17:27:16.000Z    Province1    District1    Ward2    Village2
# 4  2017-04-02T17:27:35.000Z    Province1    District1    Ward2    Village2
#
#    A11_years_farm A12_agr_assoc  ... F13_du_look_aftr_cows  F_liv_count  \
# ...

# %%
#Removing a row from a dataframe

df_SAFI.drop([4], axis='index')
# Out:
#      Column1 A01_interview_date  A03_quest_no                 A04_start  \
# 0          0         17/11/2016             1  2017-03-23T09:49:57.000Z
# 1          1         17/11/2016             1  2017-04-02T09:48:16.000Z
# 2          2         17/11/2016             3  2017-04-02T14:35:26.000Z
# 3          3         17/11/2016             4  2017-04-02T14:55:18.000Z
# 5          5         17/11/2016             6  2017-04-02T15:27:25.000Z
# ..       ...                ...           ...                       ...
# 126      126         18/05/2017           126  2017-05-18T04:13:37.000Z
# 127      127         04/06/2017           193  2017-06-04T09:36:20.000Z
# 128      128         04/06/2017           194  2017-06-04T10:13:36.000Z
# 129      129         04/06/2017           199  2017-06-04T10:33:55.000Z
# 130      130         04/06/2017           200  2017-06-04T10:52:46.000Z
#
#                       A05_end A06_province A07_district A08_ward A09_village  \
# ...

# %%
#Find the number of null (NaN) values for each column in a dataframe

df_SAFI.isnull().sum()
# Out:
# Column1                             0
# A01_interview_date                  0
# A03_quest_no                        0
# A04_start                           0
# A05_end                             0
# A06_province                        0
# A07_district                        0
# A08_ward                            0
# A09_village                         0
# A11_years_farm                      0
# A12_agr_assoc                       0
# B11_remittance_money                0
# B16_years_liv                       0
# B17_parents_liv                     0
# B18_sp_parents_liv                  0
# B19_grand_liv                       0
# B20_sp_grand_liv                    0
# B_no_membrs                         0
# C01_respondent_roof_type            0
# C02_respondent_wall_type            0
# C02_respondent_wall_type_other    131
# C03_respondent_floor_type           0
# C04_window_type                     0
# C05_buildings_in_compound           0
# C06_rooms                           0
# ...

# %%
_#Find the number of null values for a particular column

df_SAFI['E19_period_use'].isnull().sum()
# Out:
# 39

# %%
#Find the number of rows and columns in a dataframe


df_SAFI.shape
# Out:
# (131, 55)

# %%
#Use dropna() to remove ALL rows that contain null values in a dataframe

df_SAFI.dropna(inplace=True)
print(df_SAFI.shape)
# Out:
# (0, 55)

# %%
#Use dropna() to remove all columns with NaN values
df_SAFI =  pd.read_csv("SAFI_results.csv")

df_SAFI.dropna(inplace=True, axis="columns")
print(df_SAFI.shape)
# Out:
# (131, 39)

# %%
#Use dropna() to remove rows in a dataframe that have Nan values in a particular column

df_SAFI = pd.read_csv("SAFI_results.csv")

df_SAFI = df_SAFI[(df_SAFI['E_no_group_count'].notnull())]
print(df_SAFI.shape)
# Out:
# (131, 55)

# %%
#Using describe to count how many values in a column that have values (non-null)

df_SAFI = pd.read_csv("SAFI_results.csv")
df_SAFI['E19_period_use'].describe()
# Out:
# count    92.000000
# mean     12.043478
# std       8.583031
# min       1.000000
# 25%       4.000000
# 50%      10.000000
# 75%      20.000000
# max      45.000000
# Name: E19_period_use, dtype: float64

# %%
#Replacing the NaN values with 0 (notice how total values count goes up, affecting statistical calculations)

df_SAFI['E19_period_use'].fillna(0, inplace=True)
df_SAFI['E19_period_use'].describe()
# Out:
# <ipython-input-39-3fc55b9b2315>:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_SAFI['E19_period_use'].fillna(0, inplace=True)
# count    131.000000
# mean       8.458015
# std        9.062399
# min        0.000000
# 25%        0.000000
# 50%        5.000000
# 75%       15.500000
# max       45.000000
# Name: E19_period_use, dtype: float64

# %% [markdown]
# Exercises

# %%
#Exercise 1:

df_SAFI_subset = df_SAFI[["C01_respondent_roof_type", "C02_respondent_wall_type", "C02_respondent_wall_type_other", "C03_respondent_floor_type"]]

# %%
df_SAFI_subset.isnull().sum()
# Out:
# C01_respondent_roof_type            0
# C02_respondent_wall_type            0
# C02_respondent_wall_type_other    131
# C03_respondent_floor_type           0
# dtype: int64

# %%
col_no = len(df_SAFI_subset.columns)
row_no = len(df_SAFI_subset.index)

total_cells = col_no * row_no

null_cells = 0

for x in df_SAFI_subset.isnull().sum():
    null_cells += x

percentage_null = ((null_cells/total_cells) * 100)

print(percentage_null)
# Out:
# 25.0

# %%
total_cells
# Out:
# 524

# %% [markdown]
# ## Part 2 - Grouping, Aggregating and Combining Data

# %%
#Print the unique values in a column

pd.unique(df_SAFI['C01_respondent_roof_type'])
# Out:
# array(['grass', 'mabatisloping', 'mabatipitched'], dtype=object)

# %%
#Aggregate statistics about each unique value in a particular column

grouped_data = df_SAFI.groupby('C01_respondent_roof_type')
grouped_data.head()
# Out:
#     Column1 A01_interview_date  A03_quest_no                 A04_start  \
# 0         0         17/11/2016             1  2017-03-23T09:49:57.000Z
# 1         1         17/11/2016             1  2017-04-02T09:48:16.000Z
# 2         2         17/11/2016             3  2017-04-02T14:35:26.000Z
# 3         3         17/11/2016             4  2017-04-02T14:55:18.000Z
# 4         4         17/11/2016             5  2017-04-02T15:10:35.000Z
# 5         5         17/11/2016             6  2017-04-02T15:27:25.000Z
# 6         6         17/11/2016             7  2017-04-02T15:38:01.000Z
# 7         7         16/11/2016             8  2017-04-02T15:59:52.000Z
# 9         9         16/12/2016            10  2017-04-02T17:03:28.000Z
# 11       11         21/11/2016            12  2017-04-03T03:31:13.000Z
# 31       31         21/11/2016            32  2017-04-05T06:38:55.000Z
# 65       65         16/11/2016            66  2017-04-08T21:09:38.000Z
# ...

# %%
grouped_data.describe()
# Out:
#                          Column1                                           \
#                            count       mean        std   min    25%   50%
# C01_respondent_roof_type
# grass                       73.0  61.191781  37.803460   0.0  30.00  59.0
# mabatipitched               10.0  74.500000  20.045781  31.0  66.25  74.0
# mabatisloping               48.0  68.812500  40.779457   2.0  31.75  74.0
#
#                                         A03_quest_no             ...  \
#                              75%    max        count       mean  ...
# C01_respondent_roof_type                                         ...
# grass                      89.00  128.0         73.0  82.342466  ...
# mabatipitched              88.25   99.0         10.0  90.000000  ...
# mabatisloping             104.25  130.0         48.0  89.291667  ...
#
#                          gps:Latitude            gps:Longitude             \
#                                   75%        max         count       mean
# ...

# %%
#Group by multiple column values

grouped_data = df_SAFI.groupby(['C03_respondent_floor_type','C01_respondent_roof_type',
                                'C02_respondent_wall_type'])
grouped_data.describe()
# Out:
#                                                                             Column1  \
#                                                                               count
# C03_respondent_floor_type C01_respondent_roof_type C02_respondent_wall_type
# cement                    grass                    burntbricks                  4.0
#                                                    muddaub                      3.0
#                                                    sunbricks                    1.0
#                           mabatipitched            burntbricks                  3.0
#                           mabatisloping            burntbricks                 23.0
#                                                    cement                       1.0
#                                                    sunbricks                    3.0
# earth                     grass                    burntbricks                 18.0
# ...

# %%
#Generate summary statistics about aggregated data

years_farm = df_SAFI.groupby(['C01_respondent_roof_type',
                              'C02_respondent_wall_type'])['A11_years_farm'].count()
years_farm
# Out:
# C01_respondent_roof_type  C02_respondent_wall_type
# grass                     burntbricks                 22
#                           muddaub                     42
#                           sunbricks                    9
# mabatipitched             burntbricks                  6
#                           muddaub                      3
#                           sunbricks                    1
# mabatisloping             burntbricks                 39
#                           cement                       1
#                           muddaub                      1
#                           sunbricks                    7
# Name: A11_years_farm, dtype: int64

# %%
df_africa = pd.read_csv("gdp_africa.csv", index_col=0)

# %%
df_africa.head()
# Out:
#               gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Algeria          2449.008185     3013.976023     2550.816880     3246.991771
# Angola           3520.610273     3827.940465     4269.276742     5522.776375
# Benin            1062.752200      959.601080      949.499064     1035.831411
# Botswana          851.241141      918.232535      983.653976     1214.709294
# Burkina Faso      543.255241      617.183465      722.512021      794.826560
#
#               gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Algeria          4182.663766     4910.416756     5745.160213     5681.358539
# Angola           5473.288005     3008.647355     2756.953672     2430.208311
# Benin            1085.796879     1029.161251     1277.897616     1225.856010
# Botswana         2263.611114     3214.857818     4551.142150     6205.883850
# Burkina Faso      854.735976      743.387037      807.198586      912.063142
#
# ...

# %%
df_europe = pd.read_csv("gdp_europe.csv", index_col=0)

# %%
#Using concat to join rows

df_all_rows = pd.concat([df_africa, df_europe])
df_all_rows
# Out:
#                 gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria            2449.008185     3013.976023     2550.816880
# Angola             3520.610273     3827.940465     4269.276742
# Benin              1062.752200      959.601080      949.499064
# Botswana            851.241141      918.232535      983.653976
# Burkina Faso        543.255241      617.183465      722.512021
# ...                        ...             ...             ...
# Spain              3834.034742     4564.802410     5693.843879
# Sweden             8527.844662     9911.878226    12329.441920
# Switzerland       14734.232750    17909.489730    20431.092700
# Turkey             1969.100980     2218.754257     2322.869908
# United Kingdom     9979.508487    11283.177950    12477.177070
#
#                 gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Algeria            3246.991771     4182.663766     4910.416756
# ...

# %%
#Generate summary statistics of the concatenated dataframe

df_all_rows.describe()
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       82.000000       82.000000       82.000000       82.000000
# mean      2865.432820     3425.886094     4073.959797     5011.385736
# std       2940.214615     3600.092475     4291.284227     5337.033937
# min        298.846212      335.997115      355.203227      412.977514
# 25%        851.816085      908.953306      987.182010     1054.972782
# 50%       1534.765883     1615.602532     1792.525777     2112.201448
# 75%       3980.505960     4961.223547     6221.519551     7993.060987
# max      14734.232750    17909.489730    20431.092700    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       82.000000       82.000000       82.000000       82.000000
# mean      6049.356981     6865.709460     7287.557688     7745.464748
# std       6466.802893     7436.380543     7877.790932     8749.849386
# ...

# %%
#Using concat to join columns

df_all_columns = pd.concat([df_africa, df_europe], axis=1)
df_all_columns
# Out:
#                 gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Algeria            2449.008185     3013.976023     2550.816880
# Angola             3520.610273     3827.940465     4269.276742
# Benin              1062.752200      959.601080      949.499064
# Botswana            851.241141      918.232535      983.653976
# Burkina Faso        543.255241      617.183465      722.512021
# ...                        ...             ...             ...
# Spain                      NaN             NaN             NaN
# Sweden                     NaN             NaN             NaN
# Switzerland                NaN             NaN             NaN
# Turkey                     NaN             NaN             NaN
# United Kingdom             NaN             NaN             NaN
#
#                 gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Algeria            3246.991771     4182.663766     4910.416756
# ...

# %%
#Concatenating dataframes with different columns

df_mixed = pd.concat([df_europe, df_SAFI])
df_mixed
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# ...                                ...             ...             ...
# 126                                NaN             NaN             NaN
# 127                                NaN             NaN             NaN
# 128                                NaN             NaN             NaN
# 129                                NaN             NaN             NaN
# 130                                NaN             NaN             NaN
#
#                         gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# ...

# %%
students_df = pd.read_csv("students.csv", index_col=0)

grades_df = pd.read_csv("grades.csv", index_col=0)

# %%
students_df.head()
# Out:
#    student_id     name      major
# 0           1    Alice       Math
# 1           2      Bob    Physics
# 2           3  Charlie  Chemistry
# 3           4    David    Biology
# 4           5      Eve       Math

# %%
grades_df.head()
# Out:
#    student_id   name final_grade
# 0           1  Alice           A
# 1           2    Bob          B+
# 2           6  Frank          A-
# 3           7  Grace           B

# %%
# 1. Inner Join: Students present in both dataframes
inner_merged = pd.merge(students_df, grades_df, on=['student_id', 'name'], how='inner')
inner_merged

# %%
# 2. Outer Join: All students from both dataframes
outer_merged = pd.merge(students_df, grades_df, on=['student_id', 'name'], how='outer')
outer_merged

# %%
# 3. Left Join: All students from students_df and matching grades from grades_df
left_merged = pd.merge(students_df, grades_df, on=['student_id', 'name'], how='left')
left_merged

# %%
# 4. Right Join: All students from grades_df and matching info from students_df
right_merged = pd.merge(students_df, grades_df, on=['student_id', 'name'], how='right')
right_merged

# %% [markdown]
# ## Exercise 2

# %%
#Exercise 2 Part 1-2 (Read in the SAFI_results.csv dataset. Get a list of the different C01_respondent_roof_type values.)

import numpy as np
df_SAFI = pd.read_csv("SAFI_results.csv")
print(pd.unique(df_SAFI['C01_respondent_roof_type']))

# %%
#Exercise 2 Part 3 (Groupby C01_respondent_roof_type and describe the results.)
grouped_data = df_SAFI.groupby('C01_respondent_roof_type')
grouped_data.describe()

# %%
#Exercise 2 Part 3

merged_df = pd.merge(students_df, grades_df, on='student_id', how='left')
merged_df
